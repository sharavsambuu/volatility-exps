# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy  as np

# %%
# !mkdir -p ./data
# !wget -O ./data/BTCUSD_PERP-1m-2021-12.zip https://data.binance.vision/data/futures/cm/monthly/klines/BTCUSD_PERP/1m/BTCUSD_PERP-1m-2021-12.zip
# !cd ./data && unzip -o ./*.zip
# Out:
# --2022-01-23 06:23:32--  https://data.binance.vision/data/futures/cm/monthly/klines/BTCUSD_PERP/1m/BTCUSD_PERP-1m-2021-12.zip
# Resolving data.binance.vision (data.binance.vision)... 13.225.103.31, 13.225.103.48, 13.225.103.102, ...
# Connecting to data.binance.vision (data.binance.vision)|13.225.103.31|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1716744 (1.6M) [binary/octet-stream]
# Saving to: ‘./data/BTCUSD_PERP-1m-2021-12.zip’
#
# ./data/BTCUSD_PERP- 100%[===================>]   1.64M  4.06MB/s    in 0.4s
#
# 2022-01-23 06:23:34 (4.06 MB/s) - ‘./data/BTCUSD_PERP-1m-2021-12.zip’ saved [1716744/1716744]
#
# Archive:  ./BTCUSD_PERP-1m-2021-12.zip
#   inflating: BTCUSD_PERP-1m-2021-12.csv

# %%
df = pd.read_csv("./data/BTCUSD_PERP-1m-2021-12.csv", 
        names=[
            "datetime", "open", "high", "low", "close", "volume",
            "close_dt", "quote_asset_volume", "number_of_trades", 
            "taker_buy_base_volume", "taker_buy_quote_volume", "col12"
        ],
        header=None
        )

df
# Out:
#             datetime     open     high      low    close  volume  \
# 0      1638316800000  56995.7  57078.4  56898.1  56899.4  245564
# 1      1638316860000  56899.4  56918.9  56738.7  56782.1  177135
# 2      1638316920000  56782.1  56796.5  56702.6  56710.0  246997
# 3      1638316980000  56710.8  56857.2  56695.1  56812.8  190718
# 4      1638317040000  56812.7  56924.6  56802.8  56879.1   79294
# ...              ...      ...      ...      ...      ...     ...
# 44635  1640994900000  46271.5  46271.5  46251.0  46251.0    4403
# 44636  1640994960000  46251.0  46263.7  46246.4  46251.5   20011
# 44637  1640995020000  46251.5  46263.8  46249.6  46250.0   11612
# 44638  1640995080000  46250.0  46250.0  46137.7  46178.1   81034
# 44639  1640995140000  46178.1  46220.0  46178.1  46202.8   28583
#
#             close_dt  quote_asset_volume  number_of_trades  \
# 0      1638316859999          431.053665              2938
# 1      1638316919999          311.651138              1878
# 2      1638316979999          435.188447              2671
# 3      1638317039999          335.919841              2368
# 4      1638317099999          139.399370              1232
# ...              ...                 ...               ...
# 44635  1640994959999            9.517469               154
# 44636  1640995019999           43.263942               308
# 44637  1640995079999           25.105110               186
# 44638  1640995139999          175.460868              1635
# 44639  1640995199999           61.864530               535
#
#        taker_buy_base_volume  taker_buy_quote_volume  col12
# 0                      96995              170.286070      0
# 1                      67519              118.773453      0
# 2                     123151              216.994648      0
# 3                     117345              206.667562      0
# 4                      41095               72.253166      0
# ...                      ...                     ...    ...
# 44635                   1637                3.538715      0
# 44636                  12432               26.880166      0
# 44637                   9235               19.966498      0
# 44638                  31911               69.116654      0
# 44639                  19832               42.928565      0
#
# [44640 rows x 12 columns]

# %%
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'    ] = 100

# %%
df['close'].plot()
# Out:
# <AxesSubplot:>

# %%
df['volume'].plot()
# Out:
# <AxesSubplot:>
